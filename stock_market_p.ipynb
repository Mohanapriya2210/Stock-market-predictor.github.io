# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohanapriya2210/Stock-market-predictor.github.io/blob/main/stock_market_p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas_datareader as data

# %%
pip install --upgrade yfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.4/117.4 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 64.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.57
#     Uninstalling yfinance-0.2.57:
#       Successfully uninstalled yfinance-0.2.57
# ...

# %%
import pandas as pd
import yfinance as yf

start = '2020-01-01'
end = '2025-03-20'

df = yf.download('AAPL', start=start, end=end,auto_adjust=False)
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.716080  75.087502  75.150002  73.797501  74.059998  135480400
# 2020-01-03  72.009125  74.357498  75.144997  74.125000  74.287498  146322800
# 2020-01-06  72.582901  74.949997  74.989998  73.187500  73.447502  118387200
# 2020-01-07  72.241562  74.597504  75.224998  74.370003  74.959999  108872000
# 2020-01-08  73.403641  75.797501  76.110001  74.290001  74.290001  132079200

# %%
df.tail()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2025-03-13  209.679993  209.679993  216.839996  208.419998  215.949997
# 2025-03-14  213.490005  213.490005  213.949997  209.580002  211.250000
# 2025-03-17  214.000000  214.000000  215.220001  209.970001  213.309998
# 2025-03-18  212.690002  212.690002  215.149994  211.490005  214.160004
# 2025-03-19  215.240005  215.240005  218.759995  213.750000  214.220001
#
# Price         Volume
# Ticker          AAPL
# Date
# 2025-03-13  61368300
# 2025-03-14  60107600
# 2025-03-17  48073400
# 2025-03-18  42432400
# 2025-03-19  54385400

# %%
df.reset_index()
df.head()
# Out:
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.716080  75.087502  75.150002  73.797501  74.059998  135480400
# 2020-01-03  72.009125  74.357498  75.144997  74.125000  74.287498  146322800
# 2020-01-06  72.582901  74.949997  74.989998  73.187500  73.447502  118387200
# 2020-01-07  72.241562  74.597504  75.224998  74.370003  74.959999  108872000
# 2020-01-08  73.403641  75.797501  76.110001  74.290001  74.290001  132079200

# %%
df=df.drop(['Adj Close'],axis=1)
df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  75.087502  75.150002  73.797501  74.059998  135480400
# 2020-01-03  74.357498  75.144997  74.125000  74.287498  146322800
# 2020-01-06  74.949997  74.989998  73.187500  73.447502  118387200
# 2020-01-07  74.597504  75.224998  74.370003  74.959999  108872000
# 2020-01-08  75.797501  76.110001  74.290001  74.290001  132079200

# %%
plt.plot(df.Close)

# %%
df
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   75.087502   75.150002   73.797501   74.059998  135480400
# 2020-01-03   74.357498   75.144997   74.125000   74.287498  146322800
# 2020-01-06   74.949997   74.989998   73.187500   73.447502  118387200
# 2020-01-07   74.597504   75.224998   74.370003   74.959999  108872000
# 2020-01-08   75.797501   76.110001   74.290001   74.290001  132079200
# ...                ...         ...         ...         ...        ...
# 2025-03-13  209.679993  216.839996  208.419998  215.949997   61368300
# 2025-03-14  213.490005  213.949997  209.580002  211.250000   60107600
# 2025-03-17  214.000000  215.220001  209.970001  213.309998   48073400
# 2025-03-18  212.690002  215.149994  211.490005  214.160004   42432400
# 2025-03-19  215.240005  218.759995  213.750000  214.220001   54385400
#
# [1310 rows x 5 columns]

# %%
ma100=df.Close.rolling(100).mean()
ma100
# Out:
# Ticker            AAPL
# Date
# 2020-01-02         NaN
# 2020-01-03         NaN
# 2020-01-06         NaN
# 2020-01-07         NaN
# 2020-01-08         NaN
# ...                ...
# 2025-03-13  236.298799
# 2025-03-14  236.112199
# 2025-03-17  235.902199
# 2025-03-18  235.664299
# 2025-03-19  235.458100
#
# [1310 rows x 1 columns]

# %%
print(ma100.head(105))
# Out:
# Ticker           AAPL
# Date
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# ...               ...
# 2020-05-27  73.053575
# 2020-05-28  73.105625
# 2020-05-29  73.150975
# 2020-06-01  73.209625
# 2020-06-02  73.260000
#
# [105 rows x 1 columns]

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')

# %%
ma200=df.Close.rolling(200).mean()
ma200
# Out:
# Ticker           AAPL
# Date
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# ...               ...
# 2025-03-13  227.65515
# 2025-03-14  227.77270
# 2025-03-17  227.89275
# 2025-03-18  228.00475
# 2025-03-19  228.12450
#
# [1310 rows x 1 columns]

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')
plt.plot(ma200,'g')

# %%
df.shape
# Out:
# (1310, 5)

# %%
#splitting data into  training and testing

data_training=pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing=pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])
print(data_training.shape)
print(data_testing.shape)
# Out:
# (916, 1)
# (394, 1)

# %%
data_training.head()
# Out:
# Ticker           AAPL
# Date
# 2020-01-02  75.087502
# 2020-01-03  74.357498
# 2020-01-06  74.949997
# 2020-01-07  74.597504
# 2020-01-08  75.797501

# %%
data_testing.head()
# Out:
# Ticker            AAPL
# Date
# 2023-08-23  181.119995
# 2023-08-24  176.380005
# 2023-08-25  178.610001
# 2023-08-28  180.190002
# 2023-08-29  184.119995

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))

# %%
data_training_array=scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.13533301],
#        [0.13013198],
#        [0.13435334],
#        [0.13184194],
#        [0.14039152],
#        [0.15186223],
#        [0.15310901],
#        [0.16491815],
#        [0.15729476],
#        [0.15490801],
#        [0.16185454],
#        [0.16807085],
#        [0.16422352],
#        [0.16623625],
#        [0.16896143],
#        [0.16732274],
#        [0.15065105],
#        [0.16621842],
#        [0.17806316],
#        [0.17722601],
#        [0.1516485 ],
#        [0.1501345 ],
#        [0.16828458],
#        [0.17291562],
#        [0.17961277],
#        [0.17038634],
#        [0.1730937 ],
#        [0.16963823],
#        [0.18315733],
#        [0.17900718],
#        [0.1791497 ],
#        [0.16855174],
#        [0.17678072],
#        [0.17086724],
#        [0.15795379],
#        [0.13146786],
#        [0.11347807],
#        [0.12161801],
#        [0.0875443 ],
#        [0.0872593 ],
#        [0.13259   ],
#        [0.11568675],
#        [0.13958997],
# ...

# %%
x_train=[]
y_train=[]

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])

x_train, y_train=np.array(x_train),np.array(y_train)

# %%
from keras.layers import Dense,Dropout,LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units=50, activation='relu', return_sequences=True,input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units=60, activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(units=80, activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(units=120, activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(LSTM(units=120, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 351ms/step - loss: 0.0080
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 427ms/step - loss: 0.0058
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 404ms/step - loss: 0.0059
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 407ms/step - loss: 0.0047
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 355ms/step - loss: 0.0055
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 406ms/step - loss: 0.0060
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - loss: 0.0187
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 412ms/step - loss: 0.0062
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 366ms/step - loss: 0.0053
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 11s 405ms/step - loss: 0.0063
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 401ms/step - loss: 0.0058
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 404ms/step - loss: 0.0062
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 405ms/step - loss: 0.0043
# Epoch 14/50
# ...

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
data_testing.head()
# Out:
# Ticker            AAPL
# Date
# 2023-08-23  181.119995
# 2023-08-24  176.380005
# 2023-08-25  178.610001
# 2023-08-28  180.190002
# 2023-08-29  184.119995

# %%
data_training.tail(100)
# Out:
# Ticker            AAPL
# Date
# 2023-03-30  162.360001
# 2023-03-31  164.899994
# 2023-04-03  166.169998
# 2023-04-04  165.630005
# 2023-04-05  163.759995
# ...                ...
# 2023-08-16  176.570007
# 2023-08-17  174.000000
# 2023-08-18  174.490005
# 2023-08-21  175.839996
# 2023-08-22  177.229996
#
# [100 rows x 1 columns]

# %%
past_100_days=data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
# Ticker        AAPL
# 0       162.360001
# 1       164.899994
# 2       166.169998
# 3       165.630005
# 4       163.759995

# %%
input_data=scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.02284669],
#        [0.04852394],
#        [0.06136265],
#        [0.05590376],
#        [0.03699948],
#        [0.04609784],
#        [0.01951065],
#        [0.0070764 ],
#        [0.        ],
#        [0.05519604],
#        [0.05165792],
#        [0.05185999],
#        [0.06439543],
#        [0.07612212],
#        [0.06621501],
#        [0.04973715],
#        [0.05287097],
#        [0.03710068],
#        [0.03699948],
#        [0.08400727],
#        [0.09684582],
#        [0.09593603],
#        [0.08532136],
#        [0.07430239],
#        [0.05752111],
#        [0.13617068],
#        [0.13546296],
#        [0.11797412],
#        [0.13606949],
#        [0.13799026],
#        [0.1260615 ],
#        [0.12100691],
#        [0.12100691],
#        [0.12727455],
#        [0.15113222],
#        [0.15224424],
#        [0.14253936],
#        [0.11585113],
#        [0.11868168],
#        [0.13030734],
#        [0.15497361],
#        [0.17387788],
#        [0.17337239],
# ...

# %%
input_data.shape
# Out:
# (494, 1)

# %%
x_test=[]
y_test=[]

for i in range(100,input_data.shape[0]):
  x_test.append(input_data[i-100:i])
  y_test.append(input_data[i,0])

# %%
x_test,y_test=np.array(x_test),np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (394, 100, 1)
# (394,)

# %%
#making prediction

y_predicted=model.predict(x_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step

# %%
y_predicted.shape
# Out:
# (394, 1)

# %%
y_test
# Out:
# array([0.21249487, 0.16457745, 0.18712088, 0.20309341, 0.24282241,
#        0.27850781, 0.28073184, 0.29680556, 0.29923166, 0.23059039,
#        0.17650621, 0.18277385, 0.19470277, 0.1637687 , 0.14264055,
#        0.15810758, 0.15072777, 0.18065101, 0.19177117, 0.15558029,
#        0.13980984, 0.14850374, 0.16154467, 0.11989489, 0.1044277 ,
#        0.10705619, 0.11231301, 0.13799026, 0.1243428 , 0.13708047,
#        0.14971694, 0.17579865, 0.19096242, 0.18489685, 0.19915083,
#        0.20835022, 0.18954714, 0.1882329 , 0.17236141, 0.15911841,
#        0.15527702, 0.12919532, 0.13040837, 0.13485644, 0.11120099,
#        0.06864127, 0.0820865 , 0.10301242, 0.10786494, 0.14021429,
#        0.1766074 , 0.16730682, 0.19338853, 0.21957142, 0.23038816,
#        0.2255358 , 0.26587133, 0.24969674, 0.27638497, 0.28214712,
#        0.29933285, 0.29913063, 0.31692273, 0.30873432, 0.31550745,
#        0.30196118, 0.30014145, 0.30630806, 0.29589561, 0.30175896,
# ...

# %%
y_predicted
# Out:
# array([[0.27639642],
#        [0.269448  ],
#        [0.26290792],
#        [0.25680712],
#        [0.2511639 ],
#        [0.24599616],
#        [0.24137083],
#        [0.23742253],
#        [0.2344153 ],
#        [0.23266642],
#        [0.23222622],
#        [0.23274575],
#        [0.23373461],
#        [0.23481396],
#        [0.23570451],
#        [0.23623624],
#        [0.23632625],
#        [0.23597781],
#        [0.23522213],
#        [0.23411478],
#        [0.23272644],
#        [0.23112568],
#        [0.22937319],
#        [0.22752285],
#        [0.22561832],
#        [0.22369348],
#        [0.2217747 ],
#        [0.21988247],
#        [0.21803415],
#        [0.21624382],
#        [0.2145245 ],
#        [0.21288852],
#        [0.21134657],
#        [0.20990874],
#        [0.2085838 ],
#        [0.20737872],
#        [0.2063024 ],
#        [0.20536308],
#        [0.20456761],
#        [0.20391414],
#        [0.2033929 ],
#        [0.20298788],
#        [0.20267668],
# ...

# %%
scaler.scale_
# Out:
# array([0.01010918])

# %%
scale_factor=1/0.00503037
y_predicted=y_predicted*scale_factor
y_test=y_test*scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,'b',label='Original Price')
plt.plot(y_predicted,'r',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from google.colab import files

# Save and download the brain of your AI (the trained model)
model.save('stock_predictor.h5')
files.download('stock_predictor.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
